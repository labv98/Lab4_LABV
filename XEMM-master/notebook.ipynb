# %% [markdown]
# <center> <img src="http://oci02.img.iteso.mx/identidad_de_instancia_2018/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg" align="center" width="960" height="480"/> </center>

# %% [markdown]
# <center><font color=#555555><font size=6> MAF1731 - Microstructure and Trading Systems </font> <br> <br>
#
# <center><font color=#555555><font size=5> B.Eng Financial Engineering </font> <br> <br> <br> <br>
#
# <center><font color='navy'><font size=6> I.F. Barragán Vázquez Lizbeth Alejandra </font> <br> <br>
#
# <center> <font color= #555555> <font size = 4> November 08th 2021 </a> | <font color= #555555> <font size = 4> Repository: <a href='https://github.com/labv98/Lab4_LABV.git'>Link</a></font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <center> <font color= #555555> <font size = 6> Laboratory 4 </font> <br> <br> <font color= #555555> <font size = 5> Microestructura del mercado  </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>

# %% [markdown]
# <font color= 'navy'> <font size = 4> Abstract </font>

# %% [markdown]
# <font size = 3>  En el presente notebook se encuentra el análisis de ciertas criptomonedas en diferentes instancias del tiempo que se denominan timestamps. Se hace una lectura del libro de órdenes proveniente de una función propia de la librería ccxt de python. Una vez realizado lo anterior, se realizan series de tiempo por cada columna de información y con ello se realizan visualizaciones para poder entender mejor el análisis. </font>

# %% [markdown]
# <font color= 'navy'> <font size = 4> Propósito </font>

# %% [markdown]
# <font size = 3> En este laboratorio usaremos información del Libro de Ordenes de Criptomonedas de diversos exchanges internacionales, con el objetivo primario de entender y visualizar la microestructura del mercado por medio del comportamiento de Libro de Ordenes y sus caracteristicas como; Matching Engine, Levels, Ask-Bid Volumnes, etc. </font>

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= 'navy'> <font size = 6> 1. Introduction </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= 'navy'> 2. Install/Load Packages and Depedencies </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# ## <font color= 'navy'> 2.2 Python Packages </font> <font color= #555555>

# %% [markdown]
# Para pode correr el presente notebook, será necesario haber instalado o ya tener el archivo _requirements.txt_ que presenta lo siguiente:

# %% [markdown]
# - pandas>=1.1.1
# - numpy>=1.19.1
# - jupyter>=1.0.0
# - chart_studio>=1.1
# - plotly>=4.14

# %% [markdown]
# ## <font color= 'navy'> 2.3 Files Dependencies </font> <font color= #555555>

# %% [markdown]
# Las dependencias necesarias para poder correr el notebook son:

# %% [markdown]
# - functions_labv.py
# - visualizations_labv.py

# %%
from functions_labv import *
from visualizations_labv import *
import pickle

# %%
# Por si existe algún warning
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# <br>

# %% [markdown]
# #### <font color= 'navy'> <center> 3.4 Columnas de pips </font>

# %% [markdown]
# # <font color= 'navy'> 3. Consumir datos de CCXT </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %%
dic_file_a = open("dic_a.pkl", "rb")
output_a = pickle.load(dic_file_a)
output_a
# Out:
# {'Exchange': ['kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
# ...

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= 'navy'> 4. Análisis de Microestructura  </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %%
df_a = pd.read_pickle("df_final_a.pkl")
df_a
# Out:
#     Exchange                    Fechas  Levels  Volume_ask  Volume_bid  \
# 0     kraken  2021-11-07T22:24:39.773Z     100     973.705    2512.959
# 1     kraken  2021-11-07T22:24:42.828Z     100     973.705    2512.959
# 2     kraken  2021-11-07T22:24:46.032Z     100     897.008    2477.065
# 3     kraken  2021-11-07T22:24:49.083Z     100     897.008    2477.065
# 4     kraken  2021-11-07T22:24:52.278Z     100    1055.993    2518.724
# ..       ...                       ...     ...         ...         ...
# 159      ftx  2021-11-07T22:25:32.007Z      20     123.668     149.790
# 160      ftx  2021-11-07T22:25:32.417Z      20     130.671     149.790
# 161      ftx  2021-11-07T22:25:32.781Z      20     138.071     158.551
# 162      ftx  2021-11-07T22:25:33.236Z      20     134.859     158.601
# 163      ftx  2021-11-07T22:25:33.645Z      20     134.859     158.930
#
#      Total_volume  Mid_price         VWAP
# 0        3486.664   4613.045  4609.492789
# ...

# %%
df_b = pd.read_pickle("df_final_b.pkl")
df_b
# Out:
#     Exchange                    Fechas  Levels   Volume_ask   Volume_bid  \
# 0     kraken  2021-11-07T22:25:45.655Z     100  4210423.115  3441180.255
# 1     kraken  2021-11-07T22:25:48.695Z     100  4210423.115  3441180.255
# 2     kraken  2021-11-07T22:25:51.841Z     100  4248766.157  3449611.818
# 3     kraken  2021-11-07T22:25:54.887Z     100  4248766.157  3449611.818
# 4     kraken  2021-11-07T22:25:58.034Z     100  4712319.660  3448834.792
# ..       ...                       ...     ...          ...          ...
# 159      ftx  2021-11-07T22:26:37.850Z      20   584988.000   295337.000
# 160      ftx  2021-11-07T22:26:38.260Z      20   594598.000   295337.000
# 161      ftx  2021-11-07T22:26:38.669Z      20   594598.000   260477.000
# 162      ftx  2021-11-07T22:26:39.079Z      20   594594.000   274537.000
# 163      ftx  2021-11-07T22:26:39.489Z      20   589901.000   291454.000
#
#      Total_volume  Mid_price      VWAP
# 0     7651603.370   0.266034  0.266061
# ...

# %%
df_c = pd.read_pickle("df_final_c.pkl")
df_c
# Out:
#     Exchange                    Fechas  Levels  Volume_ask  Volume_bid  \
# 0     kraken  2021-11-07T22:26:51.225Z     100    5139.181   10273.169
# 1     kraken  2021-11-07T22:26:54.266Z     100    5139.181   10273.169
# 2     kraken  2021-11-07T22:26:57.505Z     100    5133.237   10282.764
# 3     kraken  2021-11-07T22:27:00.554Z     100    5133.237   10282.764
# 4     kraken  2021-11-07T22:27:03.713Z     100    5111.456   10260.726
# ..       ...                       ...     ...         ...         ...
# 161      ftx  2021-11-07T22:27:43.694Z      20    2311.210     532.680
# 162      ftx  2021-11-07T22:27:44.072Z      20    1967.210     537.740
# 163      ftx  2021-11-07T22:27:44.512Z      20    1967.210     636.480
# 164      ftx  2021-11-07T22:27:44.922Z      20    2510.950     646.890
# 165      ftx  2021-11-07T22:27:45.332Z      20    2042.700     633.150
#
#      Total_volume  Mid_price        VWAP
# 0       15412.350  249.14000  249.048684
# ...

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= 'navy'> 5. Visualizaciones  </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# > En este apartado se mostrarán tres gráficos correspondientes a ciertos resultados que provienen de estadística descriptiva, métricas de atribución al desempeño y behavioral finance.
# A manera de hacerlo más interactivo se realiza con la librería *Plotly*

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Initialize figure with subplots
fig = make_subplots(
    rows=3, cols=2, subplot_titles=("Levels", "Volume_Bid", "Volume_Ask", 
                                    "Total_Volume", "Mid_price", "VWAP")
)

# Add traces
# Level
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='ftx'], y=df_a.Levels[df_a['Exchange']=='ftx'], name='ftx-ETH/USD:Level',
                         line=dict(color='slateblue')), row=1, col=1)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='kraken'], y=df_a.Levels[df_a['Exchange']=='kraken'], name='kraken-ETH/USD:Level',
                         line=dict(color='orange')), row=1, col=1)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='currencycom'], y=df_a.Levels[df_a['Exchange']=='currencycom'], name='currencycom-ETH/USD:Level',
                         line=dict(color='green')), row=1, col=1)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='coinmate'], y=df_a.Levels[df_a['Exchange']=='coinmate'], name='coinmate-ETH/USD:Level',
                         line=dict(color='salmon')), row=1, col=1)
# Volume bid
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='ftx'], y=df_a.Volume_bid[df_a['Exchange']=='ftx']), row=1, col=2)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='kraken'], y=df_a.Volume_bid[df_a['Exchange']=='kraken']), row=1, col=2)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='currencycom'], y=df_a.Volume_bid[df_a['Exchange']=='currencycom']), row=1, col=2)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='coinmate'], y=df_a.Volume_bid[df_a['Exchange']=='coinmate']), row=1, col=2)
# Volume_ask
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='ftx'], y=df_a.Volume_ask[df_a['Exchange']=='ftx']), row=2, col=1)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='kraken'], y=df_a.Volume_ask[df_a['Exchange']=='kraken']), row=2, col=1)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='currencycom'], y=df_a.Volume_ask[df_a['Exchange']=='currencycom']), row=2, col=1)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='coinmate'], y=df_a.Volume_ask[df_a['Exchange']=='coinmate']), row=2, col=1)
# Total_vol
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='ftx'], y=df_a.Total_volume[df_a['Exchange']=='ftx']), row=2, col=2)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='kraken'], y=df_a.Total_volume[df_a['Exchange']=='kraken']), row=2, col=2)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='currencycom'], y=df_a.Total_volume[df_a['Exchange']=='currencycom']), row=2, col=2)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='coinmate'], y=df_a.Total_volume[df_a['Exchange']=='coinmate']), row=2, col=2)
# Mid price
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='ftx'], y=df_a.Mid_price[df_a['Exchange']=='ftx']), row=3, col=1)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='kraken'], y=df_a.Mid_price[df_a['Exchange']=='kraken']), row=3, col=1)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='currencycom'], y=df_a.Mid_price[df_a['Exchange']=='currencycom']), row=3, col=1)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='coinmate'], y=df_a.Mid_price[df_a['Exchange']=='coinmate']), row=3, col=1)
#VWAP
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='ftx'], y=df_a.VWAP[df_a['Exchange']=='ftx']), row=3, col=2)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='kraken'], y=df_a.VWAP[df_a['Exchange']=='kraken']), row=3, col=2)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='currencycom'], y=df_a.VWAP[df_a['Exchange']=='currencycom']), row=3, col=2)
fig.add_trace(go.Scatter(x=df_a.Fechas[df_a['Exchange']=='coinmate'], y=df_a.VWAP[df_a['Exchange']=='coinmate']), row=3, col=2)



# Update title and height
fig.update_layout(title_text='ETH/USD', height=700)

fig.show()
# Out:
# <div>                            <div id="7e2409ef-b1ff-42d4-94f1-5eb63160e59c" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e2409ef-b1ff-42d4-94f1-5eb63160e59c")) {                    Plotly.newPlot(                        "7e2409ef-b1ff-42d4-94f1-5eb63160e59c",                        [{"line": {"color": "slateblue"}, "name": "ftx-ETH/USD:Level", "type": "scatter", "x": ["2021-11-07T22:24:33.946Z", "2021-11-07T22:24:34.356Z", "2021-11-07T22:24:34.766Z", "2021-11-07T22:24:35.175Z", "2021-11-07T22:24:35.688Z", "2021-11-07T22:24:36.199Z", "2021-11-07T22:24:36.633Z", "2021-11-07T22:24:37.045Z", "2021-11-07T22:24:37.428Z", "2021-11-07T22:24:37.838Z", "2021-11-07T22:24:38.247Z", "2021-11-07T22:24:38.861Z", "2021-11-07T22:24:39.271Z", "2021-11-07T22:2
# ...

# %%
df['Exchange'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/h7/rrt2rn690b95jhvqg410dr6m0000gn/T/ipykernel_3407/2722032672.py in <module>
# ----> 1 df['Exchange'].value_counts()
#
# NameError: name 'df' is not defined

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= 'navy'> 7. Conclusiones  </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= 'navy'> 8. Referencias  </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# [1] Wikipedia "Metatrader 4" recuperado de https://en.wikipedia.org/wiki/MetaTrader_4 el día 18 de octubre de 2021.
#
# [2]

# %% [markdown]
# <br>
